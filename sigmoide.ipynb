# %% [markdown]
# Criando um gráfico com sigmoid
#
# f(x) = $\frac{1}{e^{-x} + 1}$

# %%
from math import exp
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10, 10, 100)

sigmoid = np.exp(x) / (1 + np.exp(x))

plt.plot(x, sigmoid)
